# %% [markdown]
# # NameX Six Months Stats

# %% [markdown]
# We need to load in these libraries into our notebook in order to query, load, manipulate and view the data

# %%
import os
import psycopg2
import pandas as pd
import matplotlib
from datetime import datetime, timedelta
from IPython.core.display import HTML

# %load_ext sql
# %config SqlMagic.displaylimit = 5
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %% [markdown]
# This will create the connection to the database and prep the jupyter magic for SQL

# %%
connect_to_db = 'postgresql://' + \
                os.getenv('PG_READONLY_USER', '') + ":" + os.getenv('PG_READONLY_PASSWORD', '') +'@' + \
                os.getenv('PG_HOST', '') + ':' + os.getenv('PG_PORT', '5432') + '/' + os.getenv('PG_DB_NAME', '');
    
# %sql $connect_to_db
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-15-7be75239544a> in <module>
# ----> 1 current_app.logger.debug('2222222222 App Context PG_USER: ' + current_app.config['PG_USER'])
#       2 current_app.logger.debug('2222222222 App Context PG_PASSWORD: ' + current_app.config['PG_PASSWORD'])
#       3 current_app.logger.debug('2222222222 App Context PG_PASSWORD: ' + current_app.config['PG_HOST'])
#       4 current_app.logger.debug('2222222222 App Context PG_PASSWORD: ' + current_app.config['PG_PORT'])
#       5
#
# c:\dsk01\lab\namex\jobs\notebook-report\venv\lib\site-packages\werkzeug\local.py in __getattr__(self, name)
#     346         if name == "__members__":
#     347             return dir(self._get_current_object())
# --> 348         return getattr(self._get_current_object(), name)
#     349
#     350     def __setitem__(self, key, value):
#
# c:\dsk01\lab\namex\jobs\notebook-report\venv\lib\site-packages\werkzeug\local.py in _get_current_object(self)
#     305         """
#     306         if not hasattr(self.__local, "__release_local__"):
# --> 307             return self.__local()
#     308         try:
#     309             return getattr(self.__local, self.__name__)
#
# c:\dsk01\lab\namex\jobs\notebook-report\venv\lib\site-packages\flask\globals.py in _find_app()
#      50     top = _app_ctx_stack.top
#      51     if top is None:
# ---> 52         raise RuntimeError(_app_ctx_err_msg)
#      53     return top.app
#      54
#
# RuntimeError: Working outside of application context.
#
# This typically means that you attempted to use functionality that needed
# to interface with the current application object in some way. To solve
# this, set up an application context with app.app_context().  See the
# documentation for more information.

# %% [markdown]
# Simplest query to run to ensure our libraries are loaded and our DB connection is working

# %%
# %%sql
# select now() AT TIME ZONE 'PST' as current_date

# %% [markdown]
# Six month totals before running time.

# %%
# %%sql stat_six_month_completed  <<
# SELECT e.user_id
#      , (select username from users u where u.id=e.user_id) AS EXAMINER
#      , count(e.*) FILTER (WHERE e.state_cd = 'APPROVED')  AS APPROVED
#      , count(e.*) FILTER (WHERE e.state_cd = 'REJECTED')  AS REJECTED
#      , count(e.*) FILTER (WHERE e.state_cd = 'CONDITIONAL')  AS CONDITIONAL
#      , count(e.*) FILTER (WHERE e.state_cd = 'CANCELLED')  AS CANCELLED
#      , count(r.*) FILTER (WHERE r.priority_cd = 'Y')  AS PRIORITIES
#      , count(e.*) + count(r.*) FILTER (WHERE r.priority_cd = 'Y')   AS total
# FROM events e,
# requests r
# WHERE e.user_id != 1
# AND r.id = e.nr_id
# AND date((e.event_dt AT TIME ZONE 'UTC') AT TIME ZONE 'PST') > date(current_date - 1 - interval '6 months')
# AND e.state_cd in ('APPROVED','REJECTED','CONDITIONAL','CANCELLED')
# group by e.user_id
# order by e.user_id;

# %%
edt = stat_six_month_completed.DataFrame()
edt['examiner'] = edt['examiner'].str.replace('idir/','')

# %%
edt['approved_%'] = ((edt.approved + edt.conditional) / edt.total * 100).round(1)
edt['rejected_%'] = (edt.rejected / edt.total * 100).round(1)

with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    display(HTML(edt.to_html()))
    print('grand total', edt['total'].sum())

# %% [markdown]
# Save to CSV

# %%
filename = 'six_month_totals_till_' + datetime.strftime(datetime.now()-timedelta(1), '%Y-%m-%d') +'.csv'
edt.to_csv(filename, sep=',', encoding='utf-8', index=False)
